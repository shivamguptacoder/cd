# %%
n = int(input("Enter the number of production rule : "))
lst=[]
for i in range(0,n):
    lst.append(input())
grammar=[('E','.E+T'),('E','.T'),('T','.T*F'),('T','.F'),('F','.(E)'),('F','.i')]
# Out:
# Enter the no of production rule : 6
# E->E+T
# E->T
# T->T*F
# T->F
# F->(E)
# F->i

# %%
def getAugmentedGrammar(grammar):
    return {("E'",'.E')}

# %%
def closure(state):
    b=len(state)
    newState=set()
    
    for i in state:
        print(i)
        newState.add(i)
        if(i[1][-1]=='.'):
            continue
        for j in range(len(i[1])):
            if(i[1][j]=='.' and i[1][j+1].isupper()):
                for k in grammar:
                    if(k[0]==i[1][j+1]):
                        newState.add(k)
    if b==len(newState):
        return newState
    return closure(newState)

#closure(getAugmentedGrammar(grammar))

# %%
def goto(state,a):
    newState=set()
    for i in state:
        ind=i[1].index('.')
        if(ind<len(i[1])-1 and i[1][ind+1]==a):
            s=i[1].replace('.',"")
            s1=""
            for c in s:
                s1+=c
                if(c==a):
                    s1+='.'
            newState.add((i[0],s1))
    cl=closure(newState)
    return cl

# %%
queue=[closure(getAugmentedGrammar(grammar))]
allStates=[]
assoStates=[]
while(len(queue)>0):
    c=queue.pop(0)
    for i in c:
        if(i[1][-1]=='.'):
            continue
        p=i[1][i[1].index('.')+1]
        s1=goto(c,i[1][i[1].index('.')+1])
        if(s1 not in allStates):
            queue.append(s1)
            allStates.append(s1)
            assoStates.append([c,p,s1])
# Out:
# ("E'", '.E')
# ("E'", '.E')
# ('E', '.T')
# ('E', '.E+T')
# ('E', '.T')
# ('T', '.T*F')
# ("E'", '.E')
# ('T', '.F')
# ('E', '.E+T')
# ('F', '.(E)')
# ('E', '.T')
# ('T', '.T*F')
# ("E'", '.E')
# ('E', '.E+T')
# ('T', '.F')
# ('F', '.i')
# ('E', 'T.')
# ('T', 'T.*F')
# ('E', 'T.')
# ('T', 'T.*F')
# ("E'", 'E.')
# ('E', 'E.+T')
# ('T', 'F.')
# ('F', '(.E)')
# ('E', '.T')
# ('F', '(.E)')
# ('E', '.E+T')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('T', '.F')
# ('F', '(.E)')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('F', '.(E)')
# ('T', '.F')
# ('F', '.i')
# ('F', '(.E)')
# ("E'", 'E.')
# ('E', 'E.+T')
# ('F', 'i.')
# ('T', 'T*.F')
# ('F', '.i')
# ('T', 'T*.F')
# ('F', '.(E)')
# ('E', 'E+.T')
# ('T', '.F')
# ('E', 'E+.T')
# ('T', '.T*F')
# ('F', '.(E)')
# ('T', '.T*F')
# ('E', 'E+.T')
# ('T', '.F')
# ('F', '.i')
# ('E', 'T.')
# ('T', 'T.*F')
# ('E', 'T.')
# ('T', 'T.*F')
# ('F', '(E.)')
# ('E', 'E.+T')
# ('F', '(.E)')
# ('E', '.T')
# ('F', '(.E)')
# ('E', '.E+T')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('T', '.F')
# ('F', '(.E)')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('F', '.(E)')
# ('T', '.F')
# ('F', '.i')
# ('F', '(.E)')
# ('T', 'F.')
# ('F', 'i.')
# ('F', '(E.)')
# ('E', 'E.+T')
# ('F', 'i.')
# ('T', 'T*F.')
# ('F', '(.E)')
# ('E', '.T')
# ('F', '(.E)')
# ('E', '.E+T')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('T', '.F')
# ('F', '(.E)')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('F', '.(E)')
# ('T', '.F')
# ('F', '.i')
# ('F', '(.E)')
# ('F', '(.E)')
# ('E', '.T')
# ('F', '(.E)')
# ('E', '.E+T')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('T', '.F')
# ('F', '(.E)')
# ('E', '.T')
# ('T', '.T*F')
# ('E', '.E+T')
# ('F', '.(E)')
# ('T', '.F')
# ('F', '.i')
# ('F', '(.E)')
# ('E', 'E+T.')
# ('T', 'T.*F')
# ('E', 'E+T.')
# ('T', 'T.*F')
# ('T', 'F.')
# ('F', 'i.')
# ('F', '(E).')
# ('E', 'E+.T')
# ('T', '.F')
# ('E', 'E+.T')
# ('T', '.T*F')
# ('F', '.(E)')
# ('T', '.T*F')
# ('E', 'E+.T')
# ('T', '.F')
# ('F', '.i')
# ('T', 'T*.F')
# ('F', '.i')
# ('T', 'T*.F')
# ('F', '.(E)')

# %%
print("Printing all the states:")
for i in allStates:
    print(i)
print("------------------------------------------------------------------------------------------------------")
print("Printing associates:")
for i in assoStates:
    a=i[0]
    b=i[1]
    c=i[2]
    print("State :\n"+str(a)+"\nOn Goto:"+str(b)+"\nGoes to state:\n"+str(c) )
    print("\n\n")
    print("====================================================================================================")
# Out:
# Printing all the states:
# {('E', 'T.'), ('T', 'T.*F')}
# {("E'", 'E.'), ('E', 'E.+T')}
# {('T', 'F.')}
# {('E', '.T'), ('T', '.T*F'), ('E', '.E+T'), ('F', '.(E)'), ('T', '.F'), ('F', '.i'), ('F', '(.E)')}
# {('F', 'i.')}
# {('F', '.i'), ('T', 'T*.F'), ('F', '.(E)')}
# {('F', '.(E)'), ('T', '.T*F'), ('E', 'E+.T'), ('T', '.F'), ('F', '.i')}
# {('F', '(E.)'), ('E', 'E.+T')}
# {('T', 'T*F.')}
# {('E', 'E+T.'), ('T', 'T.*F')}
# {('F', '(E).')}
# ------------------------------------------------------------------------------------------------------
# Printing associates:
# State :
# {('E', '.T'), ('T', '.T*F'), ("E'", '.E'), ('T', '.F'), ('F', '.(E)'), ('E', '.E+T'), ('F', '.i')}
# On Goto:T
# Goes to state:
# {('E', 'T.'), ('T', 'T.*F')}
#
#
#
# ====================================================================================================
# State :
# {('E', '.T'), ('T', '.T*F'), ("E'", '.E'), ('T', '.F'), ('F', '.(E)'), ('E', '.E+T'), ('F', '.i')}
# On Goto:E
# Goes to state:
# {("E'", 'E.'), ('E', 'E.+T')}
#
#
#
# ====================================================================================================
# State :
# {('E', '.T'), ('T', '.T*F'), ("E'", '.E'), ('T', '.F'), ('F', '.(E)'), ('E', '.E+T'), ('F', '.i')}
# On Goto:F
# Goes to state:
# {('T', 'F.')}
#
#
#
# ====================================================================================================
# State :
# {('E', '.T'), ('T', '.T*F'), ("E'", '.E'), ('T', '.F'), ('F', '.(E)'), ('E', '.E+T'), ('F', '.i')}
# On Goto:(
# Goes to state:
# {('E', '.T'), ('T', '.T*F'), ('E', '.E+T'), ('F', '.(E)'), ('T', '.F'), ('F', '.i'), ('F', '(.E)')}
#
#
#
# ====================================================================================================
# State :
# {('E', '.T'), ('T', '.T*F'), ("E'", '.E'), ('T', '.F'), ('F', '.(E)'), ('E', '.E+T'), ('F', '.i')}
# On Goto:i
# Goes to state:
# {('F', 'i.')}
#
#
#
# ====================================================================================================
# State :
# {('E', 'T.'), ('T', 'T.*F')}
# On Goto:*
# Goes to state:
# {('F', '.i'), ('T', 'T*.F'), ('F', '.(E)')}
#
#
#
# ====================================================================================================
# State :
# {("E'", 'E.'), ('E', 'E.+T')}
# On Goto:+
# Goes to state:
# {('F', '.(E)'), ('T', '.T*F'), ('E', 'E+.T'), ('T', '.F'), ('F', '.i')}
#
#
#
# ====================================================================================================
# State :
# {('E', '.T'), ('T', '.T*F'), ('E', '.E+T'), ('F', '.(E)'), ('T', '.F'), ('F', '.i'), ('F', '(.E)')}
# On Goto:E
# Goes to state:
# {('F', '(E.)'), ('E', 'E.+T')}
#
#
#
# ====================================================================================================
# State :
# {('F', '.i'), ('T', 'T*.F'), ('F', '.(E)')}
# On Goto:F
# Goes to state:
# {('T', 'T*F.')}
#
#
#
# ====================================================================================================
# State :
# {('F', '.(E)'), ('T', '.T*F'), ('E', 'E+.T'), ('T', '.F'), ('F', '.i')}
# On Goto:T
# Goes to state:
# {('E', 'E+T.'), ('T', 'T.*F')}
#
#
#
# ====================================================================================================
# State :
# {('F', '(E.)'), ('E', 'E.+T')}
# On Goto:)
# Goes to state:
# {('F', '(E).')}
#
#
#
# ====================================================================================================
